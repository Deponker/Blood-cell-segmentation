# %% [markdown]
# ## x_train (pure images from dataset)

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
from skimage.transform import resize
from skimage.io import imread, imshow
from tensorflow import keras
data_path = '../input/mydata5'

row = 512
columns = 512

train_data_path = os.path.join(data_path, 'train')
images = os.listdir(train_data_path)
images.sort()

training_images = images[1::2]
training_masks = images[::2] 
print(len(training_images)) #20
print(len(training_masks))
x_train = np.zeros((len(training_images), row, columns, 3), dtype=np.uint8)
index = 0
for x in training_images:
    path = os.path.join(train_data_path, x)
    image = imread(path)
    image = resize(image, (row, columns), mode='constant', preserve_range=True)
   # image.resize((128,128,1))
    x_train[index] = image
    index += 1
print(x_train.shape)
#x_train = x_train / 255
#x_train = x_train.astype('float32')
imshow(x_train[0])
print(x_train.dtype)
# Out:
# 20
# 20
# (20, 512, 512, 3)
# uint8

# %% [markdown]
# # # y_train (pure masks from dataset)

# %%
y_train = np.zeros((len(training_masks), row, columns, 3), dtype=np.uint8)
#p = os.path.join(train_data_path, training_masks[0])
#i = imread(p)
#k = resize(i, (128, 128))
#imshow(k)

index = 0
for x in training_masks:
    path = os.path.join(train_data_path, x)
    image = imread(path)
    image = resize(image, (row, columns), mode='constant', preserve_range=True)
    #image.resize((128,128,1))
    y_train[index] = image
    index += 1
y_train.shape  
type(y_train)
#y_train = y_train / 255
#y_train = y_train.astype('float32')
print(y_train.dtype)
imshow(y_train[0])
# Out:
# uint8

# %% [markdown]
# # Augmentation

# %%
import albumentations as A

transform = A.Compose([
    #A.RandomCrop(width=512, height=512),
    A.HorizontalFlip(p=0.5),
    #A.VerticalFlip(p=1),
    #A.RandomRotate90(p=1),
    A.RandomBrightnessContrast(p=0.5),
    A.Blur(blur_limit=7, always_apply=True, p=1.5),
    A.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5, always_apply=True, p=0.5),
    A.GaussNoise (var_limit=(10.0, 50.0), mean=0, always_apply=True, p=0.5)
])

# %% [markdown]
# # aug_x_train (Augmented images from dataset)
# # aug_y_train (Augmented masks from dataset)

# %%
import os
import numpy as np
from skimage.io import imread, imshow
train_dir = '../input/mydata5/train'
new_images = os.listdir(train_dir)
new_images.sort()
new_training_image = new_images[1::2]
new_training_mask = new_images[::2]
aug_x_train = np.zeros((len(new_training_image), 1200, 1600, 3), dtype=np.uint8)
aug_y_train = np.zeros((len(new_training_mask), 1200, 1600, 3), dtype=np.uint8)
#print(aug_x_train.shape)
count = 0
for x in range(len(new_training_image)):
    image1 = imread(os.path.join(train_dir, new_training_image[x]))  
    mask1 = imread(os.path.join(train_dir, new_training_mask[x]))
    transformed = transform(image=image1, mask=mask1)
    #print(transformed['image'].shape)
    aug_x_train[count] = transformed['image']
    aug_y_train[count] = transformed['mask']
    count += 1
print(aug_x_train.shape)
print(aug_y_train.shape)
# Out:
# (20, 1200, 1600, 3)
# (20, 1200, 1600, 3)

# %%
imshow(aug_x_train[19])

# %%
imshow(aug_y_train[19])

# %% [markdown]
# # Augmented images + masks saved on cwd for inspection

# %%
from skimage.io import imsave
pred_dir = './new_preds'
if not os.path.exists(pred_dir):
    os.mkdir(pred_dir)
for x in range(len(aug_x_train)):
    imsave(os.path.join(pred_dir, '0' + str(x) + '_image' + '.png'), aug_x_train[x])
    imsave(os.path.join(pred_dir, '0' + str(x) + '_mask'  + '.jpg'), aug_y_train[x])

# %%
meow = os.listdir('./new_preds')
meow.sort()
meow
aug_train_image = meow[::2] 
#new_train
aug_train_mask = meow[1::2]

total_train_images = training_images + aug_train_image
total_train_images
# Out:
# ['00a02700-2ea2-4590-9e15-ffc9160fd3de.png',
#  '00c8364b-8c85-4502-bcfe-64736fe76815.png',
#  '00d04a90-80e5-4bce-9511-1b64eabb7a47.png',
#  '0a3b53c7-e7ab-4135-80aa-fd2079d727d6.png',
#  '0a747cb3-c720-4572-a661-ab5670a5c42e.png',
#  '0a7bfa8a-ee52-4f7a-b9c5-2919ecfa93ef.png',
#  '0ab56f9a-846d-49e2-a617-c6cc477fdfad.png',
#  '0ac747cd-ff32-49bf-bc1a-3e9b7702ce9c.png',
#  '0b04ec46-5119-4cda-8c35-c4e5b6f0eed0.png',
#  '0b923ab7-ebff-4079-a4bb-af7da89f374e.png',
#  '0ca25c88-457f-4f03-bbc1-98fb6663f1d1.png',
#  '0ceb4539-5c4c-487d-9826-452a88b5d537.png',
#  '0d095f3a-9243-472b-90b4-0ce8309e778c.png',
#  '0d098413-6911-4535-b70a-3c3effd8cf49.png',
#  '0d2aba33-6920-4001-bd54-59fe0bf9f50e.png',
#  '0d3c2521-da55-4df5-bf06-56b3bd4fb2fc.png',
#  '0d7bf56f-3b5a-40bd-971c-2ca33dd89b2c.png',
#  '0da07970-3146-479c-8a07-f61ed32814a9.png',
#  '0dcbf2c9-f959-4703-a72b-f6a81e66c2ea.png',
#  '0dcca702-a4ef-4fb3-a940-9c0c140b21c7.png',
#  '00_image.png',
#  '010_image.png',
#  '011_image.png',
#  '012_image.png',
#  '013_image.png',
#  '014_image.png',
#  '015_image.png',
#  '016_image.png',
#  '017_image.png',
#  '018_image.png',
#  '019_image.png',
#  '01_image.png',
#  '02_image.png',
#  '03_image.png',
#  '04_image.png',
#  '05_image.png',
#  '06_image.png',
#  '07_image.png',
#  '08_image.png',
#  '09_image.png']

# %%
total_train_masks = training_masks + aug_train_mask
total_train_masks
# Out:
# ['00a02700-2ea2-4590-9e15-ffc9160fd3de.jpg',
#  '00c8364b-8c85-4502-bcfe-64736fe76815.jpg',
#  '00d04a90-80e5-4bce-9511-1b64eabb7a47.jpg',
#  '0a3b53c7-e7ab-4135-80aa-fd2079d727d6.jpg',
#  '0a747cb3-c720-4572-a661-ab5670a5c42e.jpg',
#  '0a7bfa8a-ee52-4f7a-b9c5-2919ecfa93ef.jpg',
#  '0ab56f9a-846d-49e2-a617-c6cc477fdfad.jpg',
#  '0ac747cd-ff32-49bf-bc1a-3e9b7702ce9c.jpg',
#  '0b04ec46-5119-4cda-8c35-c4e5b6f0eed0.jpg',
#  '0b923ab7-ebff-4079-a4bb-af7da89f374e.jpg',
#  '0ca25c88-457f-4f03-bbc1-98fb6663f1d1.jpg',
#  '0ceb4539-5c4c-487d-9826-452a88b5d537.jpg',
#  '0d095f3a-9243-472b-90b4-0ce8309e778c.jpg',
#  '0d098413-6911-4535-b70a-3c3effd8cf49.jpg',
#  '0d2aba33-6920-4001-bd54-59fe0bf9f50e.jpg',
#  '0d3c2521-da55-4df5-bf06-56b3bd4fb2fc.jpg',
#  '0d7bf56f-3b5a-40bd-971c-2ca33dd89b2c.jpg',
#  '0da07970-3146-479c-8a07-f61ed32814a9.jpg',
#  '0dcbf2c9-f959-4703-a72b-f6a81e66c2ea.jpg',
#  '0dcca702-a4ef-4fb3-a940-9c0c140b21c7.jpg',
#  '00_mask.jpg',
#  '010_mask.jpg',
#  '011_mask.jpg',
#  '012_mask.jpg',
#  '013_mask.jpg',
#  '014_mask.jpg',
#  '015_mask.jpg',
#  '016_mask.jpg',
#  '017_mask.jpg',
#  '018_mask.jpg',
#  '019_mask.jpg',
#  '01_mask.jpg',
#  '02_mask.jpg',
#  '03_mask.jpg',
#  '04_mask.jpg',
#  '05_mask.jpg',
#  '06_mask.jpg',
#  '07_mask.jpg',
#  '08_mask.jpg',
#  '09_mask.jpg']

# %% [markdown]
# # total_x_train (pure images + augmented images)

# %%
total_x_train = np.zeros((len(training_images) + len(new_training_image), row, columns, 3), dtype=np.uint8)
t_path = '../input/mydata5/train'
c = 0
d = 0 
for x in total_train_images:
    if c< len(training_images):
        img = imread(os.path.join(t_path, x))
        img = resize(img, (row, columns), mode='constant', preserve_range=True)
        total_x_train[c] = img
        c += 1
    else: 
        #img2 = imread(os.path.join('./new_preds', x))
        #img2 = resize(img2, (512, 512), mode='constant', preserve_range=True)
        #total_x_train[c] = img2
        #c += 1
        total_x_train[c] = resize(aug_x_train[d], (row, columns), mode='constant', preserve_range=True)
        c += 1
        d += 1

# %%
imshow(total_x_train[19])

# %%
imshow(x_train[19])

# %%
imshow(total_x_train[38])

# %%
imshow(aug_x_train[18])

# %% [markdown]
# # total_y_train (pure masks + augmented masks)

# %%
total_y_train = np.zeros((len(training_masks)  + len(new_training_mask), row, columns, 3), dtype=np.uint8)
t_path = '../input/mydata5/train'
c = 0
d = 0 
for x in total_train_masks:
    if c< len(training_masks):
        img = imread(os.path.join(t_path, x))
        img = resize(img, (row, columns), mode='constant', preserve_range=True)
        total_y_train[c] = img
        c += 1
    else: 
        #img2 = imread(os.path.join('./new_preds', x))
        #img2 = resize(img2, (512, 512), mode='constant', preserve_range=True)
        #total_x_train[c] = img2
        #c += 1
        total_y_train[c] = resize(aug_y_train[d], (row, columns), mode='constant', preserve_range=True)
        c += 1
        d += 1

# %%
imshow(total_y_train[14])

# %%
imshow(y_train[14])

# %%
imshow(total_y_train[38])

# %%
imshow(aug_y_train[18])

# %%
print(total_x_train.shape)
print(total_y_train.shape)
print(total_x_train.dtype)
print(total_y_train.dtype)
# Out:
# (40, 512, 512, 3)
# (40, 512, 512, 3)
# uint8
# uint8

# %% [markdown]
# # Important

# %%
total_y_train = total_y_train.astype('bool')
print(total_y_train.dtype)
# Out:
# bool

# %%
''''
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
from skimage.transform import resize
from skimage.io import imread, imshow
from tensorflow import keras
data_path = '../input/data12'

row = 512
columns = 512

train_data_path = os.path.join(data_path, 'train')
images = os.listdir(train_data_path)
images.sort()

training_images = images[1::2]
training_masks = images[::2] 
print(len(training_images))
print(len(training_masks))
x_train = np.zeros((20, row, columns, 3), dtype=np.uint8)
index = 0
for x in training_images:
    path = os.path.join(train_data_path, x)
    image = imread(path)
    image = resize(image, (row, columns), mode='constant', preserve_range=True)
   # image.resize((128,128,1))
    x_train[index] = image
    index += 1
print(x_train.shape)
#x_train = x_train / 255
#x_train = x_train.astype('float32')
imshow(x_train[0])
print(x_train.dtype)
'''
# Out:
# "'\nimport os\nimport numpy as np\nfrom PIL import Image\nimport matplotlib.pyplot as plt\nimport tensorflow as tf\n%matplotlib inline\nfrom skimage.transform import resize\nfrom skimage.io import imread, imshow\nfrom tensorflow import keras\ndata_path = '../input/data12'\n\nrow = 512\ncolumns = 512\n\ntrain_data_path = os.path.join(data_path, 'train')\nimages = os.listdir(train_data_path)\nimages.sort()\n\ntraining_images = images[1::2]\ntraining_masks = images[::2] \nprint(len(training_images))\nprint(len(training_masks))\nx_train = np.zeros((20, row, columns, 3), dtype=np.uint8)\nindex = 0\nfor x in training_images:\n    path = os.path.join(train_data_path, x)\n    image = imread(path)\n    image = resize(image, (row, columns), mode='constant', preserve_range=True)\n   # image.resize((128,128,1))\n    x_train[index] = image\n    index += 1\nprint(x_train.shape)\n#x_train = x_train / 255\n#x_train = x_train.astype('float32')\nimshow(x_train[0])\nprint(x_train.dtype)\n"

# %%
'''
y_train = np.zeros((20, row, columns, 3), dtype=np.uint8)
#p = os.path.join(train_data_path, training_masks[0])
#i = imread(p)
#k = resize(i, (128, 128))
#imshow(k)

index = 0
for x in training_masks:
    path = os.path.join(train_data_path, x)
    image = imread(path)
    image = resize(image, (row, columns), mode='constant', preserve_range=True)
    #image.resize((128,128,1))
    y_train[index] = image
    index += 1
y_train.shape  
type(y_train)
#y_train = y_train / 255
#y_train = y_train.astype('float32')
print(y_train.dtype)
imshow(y_train[0])
'''
# Out:
# "\ny_train = np.zeros((20, row, columns, 3), dtype=np.uint8)\n#p = os.path.join(train_data_path, training_masks[0])\n#i = imread(p)\n#k = resize(i, (128, 128))\n#imshow(k)\n\nindex = 0\nfor x in training_masks:\n    path = os.path.join(train_data_path, x)\n    image = imread(path)\n    image = resize(image, (row, columns), mode='constant', preserve_range=True)\n    #image.resize((128,128,1))\n    y_train[index] = image\n    index += 1\ny_train.shape  \ntype(y_train)\n#y_train = y_train / 255\n#y_train = y_train.astype('float32')\nprint(y_train.dtype)\nimshow(y_train[0])\n"

# %% [markdown]
# # x_test (Images for prediction)

# %%
test_data_path = os.path.join(data_path, 'test')
images = os.listdir(test_data_path)
images.sort()
images

testing_images = images[1::2]
testing_masks = images[::2] 

x_test = np.zeros((5, row, columns, 3), dtype=np.uint8)

index = 0
for x in testing_images:
    path = os.path.join(test_data_path, x)
    image = imread(path)
    image = resize(image, (row, columns), mode='constant', preserve_range=True)
   # image.resize((128,128,1))
    x_test[index] = image
    index += 1
print(x_test.shape)  
type(x_test)
#x_test = x_test / 255
#x_test = x_test.astype('float32')
print(x_test.dtype)
imshow(x_test[0])
# Out:
# (5, 512, 512, 3)
# uint8

# %% [markdown]
# # y_test (Ground truth for prediction)

# %%
y_test = np.zeros((5, row, columns, 3), dtype=np.float32)

index = 0
for x in testing_masks:
    path = os.path.join(test_data_path, x)
    image = imread(path)
    image = resize(image, (row, columns), mode='constant', preserve_range=True)
   # image.resize((128,128,1))
    #image = image/255
    y_test[index] = image
    index += 1
print(y_test.shape)  
y_test.dtype
type(y_test)
#y_test = y_test / 255
#y_test = y_test.astype('float32')
imshow(y_test[0])
print(y_test.dtype)
# Out:
# (5, 512, 512, 3)
# float32
# /opt/conda/lib/python3.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# # Metrics for training + validation

# %%
#y_true = y_test
#y_pred = test_preds
#def dice_coef(y_true, y_pred, smooth=1):
#    y_true_f = K.flatten(y_true)
#    y_pred_f = K.flatten(y_pred)
#    intersection = K.sum(y_true_f * y_pred_f)
#    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


#def dice_coef_loss(y_true, y_pred):
#    return -dice_coef(y_true, y_pred)


#hi = y_test / 255
#hi = K.flatten(hi)
#hi = tf.convert_to_tensor(hi, dtype=None)
#pred = test_preds
#pred = K.flatten(pred)
#pred = tf.convert_to_tensor(test_preds, dtype=None)

def dice_coef(a, b):
          #  hi = K.hi
          #  hi = hi / 255
    
          #    hi = tf.convert_to_tensor(hi, dtype=None)
          #    pred = tf.convert_to_tensor(test_preds, dtype=None)
    hi = a
  #  hi = tf.dtypes.cast(hi, tf.float32)
    pred = b
    hi = K.flatten(hi)
    pred = K.flatten(pred)
    upper_part = 2 * K.sum((hi * pred))
    lower_part = K.sum(hi + pred)
    dice = upper_part / lower_part
    return dice

def dice_coef_loss(a, b):
    loss = 1 - dice_coef(a, b)
    return loss

def jaccard_index(a, b):
    hi = a 
    pred = b
    hi = K.flatten(hi)
    pred = K.flatten(pred)
    numerator = K.sum(hi * pred)
    denominator = K.sum((hi + pred) - (hi * pred))
    iou = numerator / denominator
    return iou

# %% [markdown]
# # Libraries

# %%
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# %%
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Reshape, Permute, Activation, Input, add, multiply
from keras.layers import concatenate, core, Dropout
from keras.models import Model
from keras.layers.merge import concatenate
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.layers.core import Lambda
import keras.backend as K

# %% [markdown]
# # U-net

# %%
def attention_up_and_concate(down_layer, layer, data_format='channels_first'):
    if data_format == 'channels_first':
        in_channel = down_layer.get_shape().as_list()[1]
    else:
        in_channel = down_layer.get_shape().as_list()[3]

    # up = Conv2DTranspose(out_channel, [2, 2], strides=[2, 2])(down_layer)
    up = UpSampling2D(size=(2, 2), data_format=data_format)(down_layer)

    layer = attention_block_2d(x=layer, g=up, inter_channel=in_channel // 4, data_format=data_format)

    if data_format == 'channels_first':
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=1))
    else:
        my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))

    concate = my_concat([up, layer])
    return concate

# %%
def attention_block_2d(x, g, inter_channel, data_format='channels_first'):
    # theta_x(?,g_height,g_width,inter_channel)

    theta_x = Conv2D(inter_channel, [1, 1], strides=[1, 1], data_format=data_format)(x)

    # phi_g(?,g_height,g_width,inter_channel)

    phi_g = Conv2D(inter_channel, [1, 1], strides=[1, 1], data_format=data_format)(g)

    # f(?,g_height,g_width,inter_channel)

    f = Activation('relu')(add([theta_x, phi_g]))

    # psi_f(?,g_height,g_width,1)

    psi_f = Conv2D(1, [1, 1], strides=[1, 1], data_format=data_format)(f)

    rate = Activation('sigmoid')(psi_f)

    # rate(?,x_height,x_width)

    # att_x(?,x_height,x_width,x_channel)

    att_x = multiply([x, rate])

    return att_x

# %%
from numpy import moveaxis
#Attention U-Net
def att_unet(img_w, img_h, n_label, data_format='channels_first'):
    inputs = Input((3, img_w, img_h))
    x = inputs
    
#    print('Before re-shape: ', x.get_shape())
#    print(type(x))
#    x = tf.reshape(x, [3, 512, 512])
#    x = tf.keras.backend.expand_dims(x, axis=-4)
   #    x = x.eval(session=tf.compat.v1.Session())  
   #  x = tf.keras.backend.eval(x)
   #    x = moveaxis(x, 2, 0)
   #    x = tf.convert_to_tensor(x)
#    print('After re-shape: ', x.get_shape())
    
    depth = 4
    features = 64
    skips = []
    for i in range(depth):
        x = Conv2D(features, (3, 3), activation='relu', padding='same', data_format=data_format)(x)
        x = Dropout(0.2)(x)
        x = Conv2D(features, (3, 3), activation='relu', padding='same', data_format=data_format)(x)
        skips.append(x)
        x = MaxPooling2D((2, 2), data_format='channels_first')(x)
        features = features * 2

    x = Conv2D(features, (3, 3), activation='relu', padding='same', data_format=data_format)(x)
    x = Dropout(0.2)(x)
    x = Conv2D(features, (3, 3), activation='relu', padding='same', data_format=data_format)(x)

    for i in reversed(range(depth)):
        features = features // 2
        x = attention_up_and_concate(x, skips[i], data_format=data_format)
        x = Conv2D(features, (3, 3), activation='relu', padding='same', data_format=data_format)(x)
        x = Dropout(0.2)(x)
        x = Conv2D(features, (3, 3), activation='relu', padding='same', data_format=data_format)(x)

    conv6 = Conv2D(n_label, (1, 1), padding='same', data_format=data_format)(x)
    conv7 = core.Activation('sigmoid')(conv6)
    
#    print('Before re-shape: ', x.get_shape())
    
#    conv7 = tf.reshape(conv7, [512, 512, 3])
#    print('After re-shape ', conv7.get_shape())
    #tf.squeeze(conv7, [1])
    
    model = Model(inputs=inputs, outputs=conv7)

    opt = keras.optimizers.Adam(learning_rate=0.0001)

    #model.compile(optimizer='adam', loss='binary_crossentropy')
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[dice_coef, jaccard_index])
    #model.compile(optimizer=Adam(lr=1e-5), loss=[], metrics=['accuracy', dice_coef])
    return model

# %%
model = att_unet(512,512, 3)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 3, 512, 512) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 512, 512) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 512, 512) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 512, 512) 36928       dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 256, 256) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 256, 256 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 256, 256 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 256, 256 147584      dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 128, 128 295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256, 128, 128 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 128, 128 590080      dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 256, 64, 64)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 512, 64, 64)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512, 64, 64)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 512, 64, 64)  2359808     dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 512, 32, 32)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1024, 32, 32) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024, 32, 32) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1024, 32, 32) 9438208     dropout_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 1024, 64, 64) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 256, 64, 64)  131328      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 64, 64)  262400      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 64, 64)  0           conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 64, 64)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 64, 64)    257         activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 64, 64)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 512, 64, 64)  0           conv2d_7[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1536, 64, 64) 0           up_sampling2d[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 512, 64, 64)  7078400     lambda[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512, 64, 64)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 512, 64, 64)  2359808     dropout_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 512, 128, 128 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 32896       conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 65664       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 128 0           conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 1, 128, 128)  129         activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 128, 128)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 256, 128, 128 0           conv2d_5[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 768, 128, 128 0           up_sampling2d_1[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 128, 128 1769728     lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256, 128, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 128, 128 590080      dropout_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 256 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 256, 256) 8256        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 256, 256) 16448       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 256, 256) 0           conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 256, 256) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 1, 256, 256)  65          activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 256, 256)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 128, 256, 256 0           conv2d_3[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 384, 256, 256 0           up_sampling2d_2[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 256, 256 442496      lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128, 256, 256 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 256, 256 147584      dropout_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 512, 512 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 512, 512) 2080        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 512, 512) 4128        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 512, 512) 0           conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 512, 512) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 1, 512, 512)  33          activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1, 512, 512)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 64, 512, 512) 0           conv2d_1[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 192, 512, 512 0           up_sampling2d_3[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 512, 512) 110656      lambda_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 512, 512) 0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 512, 512) 36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 3, 512, 512)  195         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 3, 512, 512)  0           conv2d_30[0][0]
# ==================================================================================================
# Total params: 31,902,759
# Trainable params: 31,902,759
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %% [markdown]
# # Input reshaped (channels first)

# %%
print(total_x_train.shape)
r_total_x_train = total_x_train.reshape((40, 3, 512, 512))
print(r_total_x_train.shape)
# Out:
# (40, 512, 512, 3)
# (40, 3, 512, 512)

# %% [markdown]
# # Input reshaped (channels first)

# %%
print(total_y_train.shape)
r_total_y_train = total_y_train.reshape((40, 3, 512, 512))
print(r_total_y_train.shape)
# Out:
# (40, 512, 512, 3)
# (40, 3, 512, 512)

# %%
print(x_train.shape)
print(y_train.shape)
filepath = "./model.h5"

earlystopper = EarlyStopping(patience=5, verbose=1)

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min' )
#mode='min'
callbacks_list = [checkpoint]
#earlystopper,
history = model.fit(r_total_x_train, r_total_y_train, validation_split=0.2, batch_size=1, epochs=20, callbacks=callbacks_list)
# Out:
# (20, 512, 512, 3)
# (20, 512, 512, 3)
# Epoch 1/25
# 32/32 [==============================] - ETA: 0s - loss: 0.7494 - dice_coef: 0.3381 - jaccard_index: 0.2059
# Epoch 00001: val_loss improved from inf to 0.68060, saving model to ./model.h5
# 32/32 [==============================] - 6s 201ms/step - loss: 0.7494 - dice_coef: 0.3381 - jaccard_index: 0.2059 - val_loss: 0.6806 - val_dice_coef: 0.4043 - val_jaccard_index: 0.2551
# Epoch 2/25
# 32/32 [==============================] - ETA: 0s - loss: 0.6465 - dice_coef: 0.3446 - jaccard_index: 0.2096
# Epoch 00002: val_loss improved from 0.68060 to 0.67326, saving model to ./model.h5
# 32/32 [==============================] - 6s 197ms/step - loss: 0.6465 - dice_coef: 0.3446 - jaccard_index: 0.2096 - val_loss: 0.6733 - val_dice_coef: 0.3982 - val_jaccard_index: 0.2502
# Epoch 3/25
# 32/32 [==============================] - ETA: 0s - loss: 0.6331 - dice_coef: 0.3450 - jaccard_index: 0.2103
# Epoch 00003: val_loss improved from 0.67326 to 0.65591, saving model to ./model.h5
# 32/32 [==============================] - 7s 205ms/step - loss: 0.6331 - dice_coef: 0.3450 - jaccard_index: 0.2103 - val_loss: 0.6559 - val_dice_coef: 0.4032 - val_jaccard_index: 0.2541
# Epoch 4/25
# 32/32 [==============================] - ETA: 0s - loss: 0.6177 - dice_coef: 0.3691 - jaccard_index: 0.2288
# Epoch 00004: val_loss improved from 0.65591 to 0.64247, saving model to ./model.h5
# 32/32 [==============================] - 7s 211ms/step - loss: 0.6177 - dice_coef: 0.3691 - jaccard_index: 0.2288 - val_loss: 0.6425 - val_dice_coef: 0.3972 - val_jaccard_index: 0.2494
# Epoch 5/25
# 32/32 [==============================] - ETA: 0s - loss: 0.6057 - dice_coef: 0.3831 - jaccard_index: 0.2387
# Epoch 00005: val_loss improved from 0.64247 to 0.62395, saving model to ./model.h5
# 32/32 [==============================] - 6s 197ms/step - loss: 0.6057 - dice_coef: 0.3831 - jaccard_index: 0.2387 - val_loss: 0.6239 - val_dice_coef: 0.4041 - val_jaccard_index: 0.2550
# Epoch 6/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5699 - dice_coef: 0.4129 - jaccard_index: 0.2628
# Epoch 00006: val_loss did not improve from 0.62395
# 32/32 [==============================] - 5s 169ms/step - loss: 0.5699 - dice_coef: 0.4129 - jaccard_index: 0.2628 - val_loss: 0.6314 - val_dice_coef: 0.4018 - val_jaccard_index: 0.2532
# Epoch 7/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5899 - dice_coef: 0.4069 - jaccard_index: 0.2576
# Epoch 00007: val_loss improved from 0.62395 to 0.62158, saving model to ./model.h5
# 32/32 [==============================] - 6s 199ms/step - loss: 0.5899 - dice_coef: 0.4069 - jaccard_index: 0.2576 - val_loss: 0.6216 - val_dice_coef: 0.4164 - val_jaccard_index: 0.2647
# Epoch 8/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5701 - dice_coef: 0.4117 - jaccard_index: 0.2616
# Epoch 00008: val_loss improved from 0.62158 to 0.61499, saving model to ./model.h5
# 32/32 [==============================] - 6s 199ms/step - loss: 0.5701 - dice_coef: 0.4117 - jaccard_index: 0.2616 - val_loss: 0.6150 - val_dice_coef: 0.4150 - val_jaccard_index: 0.2639
# Epoch 9/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5481 - dice_coef: 0.4370 - jaccard_index: 0.2819
# Epoch 00009: val_loss did not improve from 0.61499
# 32/32 [==============================] - 5s 167ms/step - loss: 0.5481 - dice_coef: 0.4370 - jaccard_index: 0.2819 - val_loss: 0.6177 - val_dice_coef: 0.4132 - val_jaccard_index: 0.2625
# Epoch 10/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5527 - dice_coef: 0.4332 - jaccard_index: 0.2792
# Epoch 00010: val_loss improved from 0.61499 to 0.60217, saving model to ./model.h5
# 32/32 [==============================] - 6s 196ms/step - loss: 0.5527 - dice_coef: 0.4332 - jaccard_index: 0.2792 - val_loss: 0.6022 - val_dice_coef: 0.4370 - val_jaccard_index: 0.2818
# Epoch 11/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5477 - dice_coef: 0.4412 - jaccard_index: 0.2860
# Epoch 00011: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 167ms/step - loss: 0.5477 - dice_coef: 0.4412 - jaccard_index: 0.2860 - val_loss: 0.6036 - val_dice_coef: 0.4387 - val_jaccard_index: 0.2836
# Epoch 12/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5361 - dice_coef: 0.4501 - jaccard_index: 0.2929
# Epoch 00012: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 169ms/step - loss: 0.5361 - dice_coef: 0.4501 - jaccard_index: 0.2929 - val_loss: 0.6139 - val_dice_coef: 0.4202 - val_jaccard_index: 0.2691
# Epoch 13/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5333 - dice_coef: 0.4617 - jaccard_index: 0.3034
# Epoch 00013: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 168ms/step - loss: 0.5333 - dice_coef: 0.4617 - jaccard_index: 0.3034 - val_loss: 0.6201 - val_dice_coef: 0.4313 - val_jaccard_index: 0.2770
# Epoch 14/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5340 - dice_coef: 0.4521 - jaccard_index: 0.2950
# Epoch 00014: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 169ms/step - loss: 0.5340 - dice_coef: 0.4521 - jaccard_index: 0.2950 - val_loss: 0.6127 - val_dice_coef: 0.4173 - val_jaccard_index: 0.2661
# Epoch 15/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5231 - dice_coef: 0.4619 - jaccard_index: 0.3035
# Epoch 00015: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 168ms/step - loss: 0.5231 - dice_coef: 0.4619 - jaccard_index: 0.3035 - val_loss: 0.6247 - val_dice_coef: 0.4108 - val_jaccard_index: 0.2612
# Epoch 16/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5531 - dice_coef: 0.4366 - jaccard_index: 0.2824
# Epoch 00016: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 168ms/step - loss: 0.5531 - dice_coef: 0.4366 - jaccard_index: 0.2824 - val_loss: 0.6403 - val_dice_coef: 0.4056 - val_jaccard_index: 0.2566
# Epoch 17/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5292 - dice_coef: 0.4549 - jaccard_index: 0.2973
# Epoch 00017: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 167ms/step - loss: 0.5292 - dice_coef: 0.4549 - jaccard_index: 0.2973 - val_loss: 0.6074 - val_dice_coef: 0.4258 - val_jaccard_index: 0.2734
# Epoch 18/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5249 - dice_coef: 0.4623 - jaccard_index: 0.3040
# Epoch 00018: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 169ms/step - loss: 0.5249 - dice_coef: 0.4623 - jaccard_index: 0.3040 - val_loss: 0.6323 - val_dice_coef: 0.4044 - val_jaccard_index: 0.2563
# Epoch 19/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5226 - dice_coef: 0.4624 - jaccard_index: 0.3035
# Epoch 00019: val_loss did not improve from 0.60217
# 32/32 [==============================] - 5s 167ms/step - loss: 0.5226 - dice_coef: 0.4624 - jaccard_index: 0.3035 - val_loss: 0.6077 - val_dice_coef: 0.4327 - val_jaccard_index: 0.2792
# Epoch 20/25
# 32/32 [==============================] - ETA: 0s - loss: 0.5130 - dice_coef: 0.4967 - jaccard_index: 0.3353
# Epoch 00020: val_loss improved from 0.60217 to 0.55784, saving model to ./model.h5
# 32/32 [==============================] - 6s 198ms/step - loss: 0.5130 - dice_coef: 0.4967 - jaccard_index: 0.3353 - val_loss: 0.5578 - val_dice_coef: 0.4827 - val_jaccard_index: 0.3214
# Epoch 21/25
# 32/32 [==============================] - ETA: 0s - loss: 0.4496 - dice_coef: 0.5843 - jaccard_index: 0.4215
# Epoch 00021: val_loss improved from 0.55784 to 0.42072, saving model to ./model.h5
# 32/32 [==============================] - 6s 197ms/step - loss: 0.4496 - dice_coef: 0.5843 - jaccard_index: 0.4215 - val_loss: 0.4207 - val_dice_coef: 0.6681 - val_jaccard_index: 0.5063
# Epoch 22/25
# 32/32 [==============================] - ETA: 0s - loss: 0.3747 - dice_coef: 0.6812 - jaccard_index: 0.5261
# Epoch 00022: val_loss improved from 0.42072 to 0.39554, saving model to ./model.h5
# 32/32 [==============================] - 6s 198ms/step - loss: 0.3747 - dice_coef: 0.6812 - jaccard_index: 0.5261 - val_loss: 0.3955 - val_dice_coef: 0.6618 - val_jaccard_index: 0.4992
# Epoch 23/25
# 32/32 [==============================] - ETA: 0s - loss: 0.3575 - dice_coef: 0.6839 - jaccard_index: 0.5289
# Epoch 00023: val_loss improved from 0.39554 to 0.37369, saving model to ./model.h5
# 32/32 [==============================] - 7s 208ms/step - loss: 0.3575 - dice_coef: 0.6839 - jaccard_index: 0.5289 - val_loss: 0.3737 - val_dice_coef: 0.6995 - val_jaccard_index: 0.5420
# Epoch 24/25
# 32/32 [==============================] - ETA: 0s - loss: 0.3203 - dice_coef: 0.7303 - jaccard_index: 0.5818
# Epoch 00024: val_loss improved from 0.37369 to 0.35259, saving model to ./model.h5
# 32/32 [==============================] - 6s 199ms/step - loss: 0.3203 - dice_coef: 0.7303 - jaccard_index: 0.5818 - val_loss: 0.3526 - val_dice_coef: 0.7096 - val_jaccard_index: 0.5533
# Epoch 25/25
# 32/32 [==============================] - ETA: 0s - loss: 0.3082 - dice_coef: 0.7346 - jaccard_index: 0.5881
# Epoch 00025: val_loss improved from 0.35259 to 0.33978, saving model to ./model.h5
# 32/32 [==============================] - 7s 231ms/step - loss: 0.3082 - dice_coef: 0.7346 - jaccard_index: 0.5881 - val_loss: 0.3398 - val_dice_coef: 0.7177 - val_jaccard_index: 0.5630

# %% [markdown]
# # Plotting history

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Binary_crossEntropy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice coeff')
plt.ylabel('Dice coeff')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['jaccard_index'])
plt.plot(history.history['val_jaccard_index'])
plt.title('Model jaccard index')
plt.ylabel('Jaccard index')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Testing

# %% [markdown]
# # Test reshaped (channels first)

# %%
print(x_test.shape)
r_x_test = x_test.reshape((5, 3, 512, 512))
print(r_x_test.shape)
# Out:
# (5, 512, 512, 3)
# (5, 3, 512, 512)

# %%
#print(y_test.shape)
#r_y_test = x_test.reshape((5, 3, 512, 512))
#print(r_y_test.shape)

# %%
#from keras.models import load_model
#model = load_model('./assets')
model.load_weights('./model.h5')

test_preds = model.predict(r_x_test)
print(test_preds.shape)
print(type(test_preds))
# Out:
# (5, 3, 512, 512)
# <class 'numpy.ndarray'>

# %%
print(type(test_preds))
print(test_preds.shape)
print(test_preds.dtype)
#print(test_preds[0])
imshow(test_preds[0].reshape(512, 512, 3))
# Out:
# <class 'numpy.ndarray'>
# (5, 3, 512, 512)
# float32

# %%
from skimage.io import imshow_collection
imshow_collection(test_preds.reshape(5, 512, 512, 3))
imshow_collection(y_test)

# %% [markdown]
# # Evaluating Individual Dice-Co efficient
# # Metrics for individual evaluation

# %%
def dice_coef2(a, b):
          #  hi = K.hi
          #  hi = hi / 255
    
          #    hi = tf.convert_to_tensor(hi, dtype=None)
          #    pred = tf.convert_to_tensor(test_preds, dtype=None)
    hi = a/255
    pred = b
    hi = K.flatten(hi)
    pred = K.flatten(pred)
    upper_part = 2 * K.sum((hi * pred))
    lower_part = K.sum(hi + pred)
    dice = upper_part / lower_part
    return dice

def jaccard_index2(a, b):
    hi = a/255
    pred = b
    hi = K.flatten(hi)
    pred = K.flatten(pred)
    numerator = K.sum(hi * pred)
    denominator = K.sum((hi + pred) - (hi * pred))
    iou = numerator / denominator
    return iou

# %%
print(y_test[0].dtype)
print(test_preds[0].dtype)
i = y_test[0]
j = test_preds[0]
#i = np.asarray(i).astype(dtype=np.float32)
result = dice_coef2(i,j)
#print(tf.get_static_value(result))
print('Dice Co-efficient: ', result)
result2 = jaccard_index2(i,j)
print('Jaccard-index: ', result2)
x = np.zeros((2, row, columns, 3))
x[0] = i
x[1] = j.reshape((512, 512, 3))
imshow_collection(x)
# Out:
# float32
# float32
# Dice Co-efficient:  tf.Tensor(0.4175045, shape=(), dtype=float32)
# Jaccard-index:  tf.Tensor(0.26382667, shape=(), dtype=float32)

# %%
print(y_test[1].dtype)
print(test_preds[1].dtype)
i = y_test[1]
j = test_preds[1]
#i = np.asarray(i).astype(dtype=np.float32)
result = dice_coef2(i,j)
#print(tf.get_static_value(result))
print('Dice Co-efficient: ', result)
result2 = jaccard_index2(i,j)
print('Jaccard-index: ', result2)
x = np.zeros((2, row, columns, 3))
x[0] = i
x[1] = j.reshape((512, 512, 3))
imshow_collection(x)
# Out:
# float32
# float32
# Dice Co-efficient:  tf.Tensor(0.8320352, shape=(), dtype=float32)
# Jaccard-index:  tf.Tensor(0.7123803, shape=(), dtype=float32)

# %%
print(y_test[2].dtype)
print(test_preds[2].dtype)
i = y_test[2]
j = test_preds[2]
#i = np.asarray(i).astype(dtype=np.float32)
result = dice_coef2(i,j)
#print(tf.get_static_value(result))
print('Dice Co-efficient: ', result)
result2 = jaccard_index2(i,j)
print('Jaccard-index: ', result2)
x = np.zeros((2, row, columns, 3))
x[0] = i
x[1] = j.reshape((512, 512, 3))
imshow_collection(x)
# Out:
# float32
# float32
# Dice Co-efficient:  tf.Tensor(0.7607378, shape=(), dtype=float32)
# Jaccard-index:  tf.Tensor(0.6138634, shape=(), dtype=float32)

# %%
print(y_test[3].dtype)
print(test_preds[3].dtype)
i = y_test[3]
j = test_preds[3]
#i = np.asarray(i).astype(dtype=np.float32)
result = dice_coef2(i,j)
#print(tf.get_static_value(result))
print('Dice Co-efficient: ', result)
result2 = jaccard_index2(i,j)
print('Jaccard-index: ', result2)
x = np.zeros((2, row, columns, 3))
x[0] = i
x[1] = j.reshape((512, 512, 3))
imshow_collection(x)
# Out:
# float32
# float32
# Dice Co-efficient:  tf.Tensor(0.8102307, shape=(), dtype=float32)
# Jaccard-index:  tf.Tensor(0.6809981, shape=(), dtype=float32)

# %%
print(y_test[4].dtype)
print(test_preds[4].dtype)
i = y_test[4]
j = test_preds[4]
#i = np.asarray(i).astype(dtype=np.float32)
result = dice_coef2(i,j)
#print(tf.get_static_value(result))
print('Dice Co-efficient: ', result)
result2 = jaccard_index2(i,j)
print('Jaccard-index: ', result2)
x = np.zeros((2, row, columns, 3))
x[0] = i
x[1] = j.reshape((512, 512, 3))
imshow_collection(x)
# Out:
# float32
# float32
# Dice Co-efficient:  tf.Tensor(0.774244, shape=(), dtype=float32)
# Jaccard-index:  tf.Tensor(0.6316461, shape=(), dtype=float32)

# %% [markdown]
# # Average Test Dice Co-efficient, Jaccard index

# %%
#dice_list = np.array(len(test_preds))
#jaccard_list = np.array(len(test_preds))
avg_dice = 0
avg_jaccard = 0
for x in range(len(test_preds)):
    i = y_test[x]
    j = test_preds[x]
    avg_dice = avg_dice + tf.get_static_value(dice_coef2(i,j))
    avg_jaccard = avg_jaccard + tf.get_static_value(jaccard_index2(i,j))
    
#print(dice_list.dtype)
#print(type(dice_list))
#print(dice_list)
#print(jaccard_list)
#avg_dice = tf.get_static_value(K.sum(dice_list)) / tf.get_static_value(tf.size(dice_list))
#avg_jaccard = tf.get_static_value(K.sum(jaccard_list)) / tf.get_static_value(tf.size(jaccard_list))
print('Average Test Dice co-efficent: ', avg_dice/len(test_preds))
print('Average Test Jaccrad Index: ', avg_jaccard/len(test_preds))
# Out:
# Average Test Dice co-efficent:  0.7189504265785217
# Average Test Jaccrad Index:  0.5805429100990296

# %%
history

# %% [markdown]
# # Highest & Lowest

# %%
print('Lowest training loss: ', min(history.history['loss']))
print('Lowest validation loss: ', min(history.history['val_loss']))
print('Highest training dice coefficient: ', max(history.history['dice_coef']))
print('Highest validation dice coefficient: ', max(history.history['val_dice_coef']))
print('Highest training jaccrad index: ', max(history.history['jaccard_index']))
print('Highest validation jaccard index: ', max(history.history['val_jaccard_index']))
# Out:
# Lowest training loss:  0.3081910312175751
# Lowest validation loss:  0.3397834897041321
# Highest training dice coefficient:  0.7345638871192932
# Highest validation dice coefficient:  0.7177466154098511
# Highest training jaccrad index:  0.588117241859436
# Highest validation jaccard index:  0.5630454421043396
